# %% [markdown]
# # Úkol 1 - Práce s listy v Pythonu
#
# **Jméno:** *(doplň své jméno)*
# **Třída:** *(doplň třídu)*
# **Datum:** *(doplň datum odevzdání)*
#
# ---

# %% [markdown]
# ## Zadání
#
# Vytvoř program, který:
# 1. Vytvoří list s 5 čísly
# 2. Přidá do listu další číslo
# 3. Odstraní z listu první prvek
# 4. Vypíše délku listu
# 5. Vypíše celý list
#
# **Bonus:** Vypočítej průměr všech čísel v listu.

# %% [markdown]
# ---
# ## Krok 1: Vytvoření listu s 5 čísly
#
# Vytvoř list a pojmenuj ho podle sebe. Můžeš použít jakákoli čísla.

# %%
# Tvůj kód zde
muj_list = 

print("Můj list:", muj_list)

# %% [markdown]
# ---
# ## Krok 2: Přidání dalšího čísla do listu
#
# Použij metodu `.append()` nebo `.insert()` k přidání nového čísla.

# %%
# Tvůj kód zde


print("List po přidání:", muj_list)

# %% [markdown]
# ---
# ## Krok 3: Odstranění prvního prvku
#
# Použij metodu `.pop()` nebo `del` k odstranění prvního prvku (index 0).

# %%
# Tvůj kód zde


print("List po odstranění:", muj_list)

# %% [markdown]
# ---
# ## Krok 4: Délka listu
#
# Použij funkci `len()` k zjištění délky listu.

# %%
# Tvůj kód zde
delka = 

print(f"Délka listu je: {delka}")

# %% [markdown]
# ---
# ## Krok 5: Výpis celého listu
#
# Vypiš všechny prvky listu.

# %%
# Tvůj kód zde
print("Finální list:", muj_list)

# %% [markdown]
# ---
# ## 🌟 BONUS: Výpočet průměru
#
# Vypočítej průměr všech čísel v listu. Můžeš použít funkce `sum()` a `len()`.

# %%
# Tvůj kód zde (bonusový úkol)
prumer = 

print(f"Průměr čísel v listu je: {prumer}")

# %% [markdown]
# ---
# ## Reflexe
#
# *(Volitelné - napiš, co se ti při úkolu podařilo, co bylo těžké, nebo co nového jsi se naučil/a)*
#
# -
# -
# -

# %% [markdown]
# ---
# ## Před odevzdáním nezapomeň:
#
# ✅ Spustit všechny buňky (`Runtime` → `Run all` v Google Colabu)
# ✅ Zkontrolovat, že všechny výstupy jsou správně
# ✅ Doplnit své jméno nahoře
# ✅ Uložit na GitHub
#
# **Hodně štěstí!** 🚀
